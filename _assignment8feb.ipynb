# %%
#Q1. What is Abstraction in OOps? Explain with an example.
ans= abstraction is a method by which we hide the internal details of application from outer world.it is used to describe the process in asimple way. basically its is boundry betweeen the application and client.
exm =
import abc
class vehical:
    
    @abc.abstractmethod
    def bike(self):
        pass
    
    def car(self):
        pass
class car(vehical):
    
    def car(self):
        return "it has 4 wheels"
    
cr = car()
cr.car()
# it has 4 wheels
    


#Q2. Differentiate between Abstraction and Encapsulation. Explain with an example.

Abstraction is a design level process . and it is used the complexity at the stage of designing level in the project.
and encapsulation is implementaion level process . which provide the security and also works on the transperancy of the project.
exm of abstraction =  suppose anyone wants to  bake the cake then those person needs of recipe of the cake.

exm of encapsulation = suppose you know how to drive and start the car by pressing the button but internal details are hidden from you.


#Q3. What is abc module in python? Why is it used?




#Q4. How can we achieve data abstraction?


#Q5. Can we create an instance of an abstract class? Explain your answer

# %%
import abc
class vehical:
    
    @abc.abstractmethod
    def bike(self):
        pass
    
    def car(self):
        pass

# %%
import abc
class vehical:
    
    @abc.abstractmethod
    def bike(self):
        pass
    
    def car(self):
        pass

# %%
class car(vehical):
    
    def car(self):
        return "it has 4 wheels"

# %%
cr = car()
cr.car()
# Out:
# 'it has 4 wheels'

# %%
bke = bike()
bke.bike()
# Out:
# 'its has 2 wheels'
